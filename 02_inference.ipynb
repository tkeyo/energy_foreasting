# %%
from darts.models import Prophet

# %%
model = Prophet.load("prophet.pkl")

# %%
model.predict_raw(12)
# Out:
#            ds         trend  ...  multiplicative_terms_upper          yhat
# 0  2021-11-30  1.702138e+06  ...                         0.0  1.928004e+06
# 1  2021-12-31  1.700806e+06  ...                         0.0  2.010065e+06
# 2  2022-01-31  1.699474e+06  ...                         0.0  2.305417e+06
# 3  2022-02-28  1.698271e+06  ...                         0.0  2.055883e+06
# 4  2022-03-31  1.696939e+06  ...                         0.0  2.062181e+06
# 5  2022-04-30  1.695649e+06  ...                         0.0  1.591987e+06
# 6  2022-05-31  1.694317e+06  ...                         0.0  1.410741e+06
# 7  2022-06-30  1.693028e+06  ...                         0.0  1.242748e+06
# 8  2022-07-31  1.691696e+06  ...                         0.0  1.155464e+06
# 9  2022-08-31  1.690364e+06  ...                         0.0  1.229514e+06
# 10 2022-09-30  1.689074e+06  ...                         0.0  1.411048e+06
# ...
